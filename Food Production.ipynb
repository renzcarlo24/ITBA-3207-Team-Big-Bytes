# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
data = pd.read_excel('FoodProduction.xlsx')

# %%
data
# Out:
#                country  year  Food_Production
# 0    Brunei Darussalam  2007             83.1
# 1    Brunei Darussalam  2008             85.7
# 2    Brunei Darussalam  2009             86.2
# 3    Brunei Darussalam  2010             90.3
# 4    Brunei Darussalam  2011             97.0
# ..                 ...   ...              ...
# 139             France  2014            103.0
# 140             France  2015            102.0
# 141             France  2016             95.3
# 142             France  2017            102.0
# 143             France  2018             98.7
#
# [144 rows x 3 columns]

# %%
bd = data[data.country == 'Brunei Darussalam']
cam = data[data.country == 'Cambodia']
ind = data[data.country == 'Indonesia']
lao = data[data.country == 'Lao People’s Dem. Rep.']
mal = data[data.country == 'Malaysia']
mya = data[data.country == 'Myanmar']
phi = data[data.country == 'Philippines']
sing = data[data.country == 'Singapore']
thai = data[data.country == 'Thailand']
tim = data[data.country == 'Timor-Leste']
viet = data[data.country == 'Vietnam']
fran = data[data.country == 'France']

# %%
bd
# Out:
#               country  year  Food_Production
# 0   Brunei Darussalam  2007             83.1
# 1   Brunei Darussalam  2008             85.7
# 2   Brunei Darussalam  2009             86.2
# 3   Brunei Darussalam  2010             90.3
# 4   Brunei Darussalam  2011             97.0
# 5   Brunei Darussalam  2012             98.8
# 6   Brunei Darussalam  2013            107.0
# 7   Brunei Darussalam  2014            100.0
# 8   Brunei Darussalam  2015             98.1
# 9   Brunei Darussalam  2016            102.0
# 10  Brunei Darussalam  2017             99.6
# 11  Brunei Darussalam  2018            100.0

# %%
f = plt.figure()
f.set_figwidth(20)
f.set_figheight(7)
plt.plot(bd.year, bd.Food_Production)
plt.plot(cam.year, cam.Food_Production)
plt.plot(ind.year, ind.Food_Production)
plt.plot(lao.year, lao.Food_Production)
plt.plot(mal.year, mal.Food_Production)
plt.plot(mya.year, mya.Food_Production)
plt.plot(phi.year, phi.Food_Production)
plt.plot(sing.year, sing.Food_Production)
plt.plot(thai.year, thai.Food_Production)
plt.plot(tim.year, tim.Food_Production)
plt.plot(viet.year, viet.Food_Production)
plt.plot(fran.year, fran.Food_Production)
plt.legend(['Brunei Darussalam', 'Cambodia', 'Indonesia', 'Lao People’s Dem. Rep.', 'Malaysia',  'Myanmar', 'Philippines', 'Singapore', 'Thailand', 'Timor-Leste', 'Vietnam', 'France'])
plt.xlabel('year')
plt.ylabel('Food_Production')
plt.show()
